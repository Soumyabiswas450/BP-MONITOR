# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumyabiswas450/BP-MONITOR/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #🌱 Multimodal Leaf Disease Detection
# > Rice

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd

print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
# Out:
# NumPy version: 2.1.3
# Pandas version: 2.2.3
